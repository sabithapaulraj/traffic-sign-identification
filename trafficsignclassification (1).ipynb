# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
with open("train.p", mode='rb') as training_data:
  train = pickle.load(training_data)

with open("valid.p", mode='rb') as validation_data:
  valid = pickle.load(validation_data)
with open("test.p", mode='rb') as testing_data:
  test = pickle.load(testing_data)

# %%
X_train , y_train = train['features'], train['labels']
X_validation , y_validation = valid['features'], valid['labels']
X_test , y_test = test['features'] , test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
X_validation.shape
# Out:
# (4410, 32, 32, 3)

# %%
y_validation.shape
# Out:
# (4410,)

# %%
X_test.shape
# Out:
# (12630, 32, 32, 3)

# %%
y_test.shape
# Out:
# (12630,)

# %%
i = 1000
plt.imshow(X_train[i])
y_train[i]
# Out:
# 36

# %%
i = 4000
plt.imshow(X_validation[i])
y_validation[i]
# Out:
# 17

# %%
i = 3000
plt.imshow(X_test[i])
y_test[i]
# Out:
# 11

# %%
i = 5000
plt.imshow(X_test[i])
y_test[i]
# Out:
# 26

# %%
from sklearn.utils import shuffle
X_train , y_train = shuffle(X_train , y_train)

# %%
X_train_grey = np.sum(X_train/3 , axis = 3 , keepdims = True)
X_test_grey = np.sum(X_test/3 , axis = 3 , keepdims = True)
X_validation_grey = np.sum(X_validation/3 , axis = 3 , keepdims = True)

# %%
X_train_grey.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_test_grey.shape
# Out:
# (12630, 32, 32, 1)

# %%
X_validation_grey.shape
# Out:
# (4410, 32, 32, 1)

# %%
X_train_grey_norm = (X_train_grey - 128)/128
X_test_grey_norm = (X_test_grey - 128)/128
X_validation_grey_norm = (X_validation_grey - 128)/128

# %%
X_train_grey_norm
# Out:
# array([[[[-0.38802083],
#          [-0.26041667],
#          [-0.203125  ],
#          ...,
#          [-0.46875   ],
#          [-0.45833333],
#          [-0.4609375 ]],
#
#         [[-0.40104167],
#          [-0.2734375 ],
#          [-0.20572917],
#          ...,
#          [-0.45833333],
#          [-0.46614583],
#          [-0.46354167]],
#
#         [[-0.40104167],
#          [-0.26041667],
#          [-0.19010417],
#          ...,
#          [-0.5078125 ],
#          [-0.515625  ],
#          [-0.5078125 ]],
#
#         ...,
#
#         [[-0.421875  ],
#          [-0.3515625 ],
#          [-0.29427083],
#          ...,
#          [-0.0390625 ],
#          [ 0.25520833],
#          [ 0.41927083]],
#
#         [[-0.25520833],
#          [-0.22395833],
#          [-0.22135417],
#          ...,
#          [ 0.01302083],
#          [ 0.27604167],
#          [ 0.42708333]],
#
#         [[-0.19010417],
#          [-0.22135417],
#          [-0.25260417],
#          ...,
#          [ 0.03645833],
#          [ 0.26822917],
#          [ 0.38802083]]],
#
#
#        [[[-0.67708333],
#          [-0.69010417],
#          [-0.68489583],
#          ...,
#          [-0.68489583],
#          [-0.69010417],
#          [-0.6875    ]],
#
#         [[-0.66666667],
#          [-0.69010417],
#          [-0.68229167],
#          ...,
#          [-0.69270833],
#          [-0.69270833],
#          [-0.68489583]],
#
#         [[-0.67447917],
#          [-0.69270833],
#          [-0.69010417],
#          ...,
#          [-0.6875    ],
#          [-0.68489583],
#          [-0.6875    ]],
#
#         ...,
#
#         [[-0.67708333],
#          [-0.68229167],
#          [-0.67447917],
#          ...,
#          [-0.66145833],
#          [-0.66927083],
#          [-0.6796875 ]],
#
#         [[-0.68229167],
#          [-0.68489583],
#          [-0.67708333],
#          ...,
#          [-0.6484375 ],
#          [-0.66145833],
#          [-0.6796875 ]],
#
#         [[-0.67708333],
#          [-0.671875  ],
#          [-0.6640625 ],
#          ...,
#          [-0.640625  ],
#          [-0.65885417],
#          [-0.66927083]]],
#
#
#        [[[-0.8828125 ],
#          [-0.88020833],
#          [-0.890625  ],
#          ...,
#          [-0.29947917],
#          [-0.26822917],
#          [-0.31510417]],
#
#         [[-0.8984375 ],
#          [-0.88802083],
#          [-0.88020833],
#          ...,
#          [-0.296875  ],
#          [-0.25      ],
#          [-0.31510417]],
#
#         [[-0.89583333],
#          [-0.88802083],
#          [-0.88020833],
#          ...,
#          [-0.35677083],
#          [-0.359375  ],
#          [-0.39583333]],
#
#         ...,
#
#         [[-0.93489583],
#          [-0.9296875 ],
#          [-0.921875  ],
#          ...,
#          [-0.9296875 ],
#          [-0.9296875 ],
#          [-0.9296875 ]],
#
#         [[-0.93229167],
#          [-0.92708333],
#          [-0.9296875 ],
#          ...,
#          [-0.9296875 ],
#          [-0.9296875 ],
#          [-0.921875  ]],
#
#         [[-0.92447917],
#          [-0.92708333],
#          [-0.9296875 ],
#          ...,
#          [-0.93229167],
#          [-0.93229167],
#          [-0.93229167]]],
#
#
#        ...,
#
#
#        [[[-0.85416667],
#          [-0.85416667],
#          [-0.86197917],
#          ...,
#          [-0.8359375 ],
#          [-0.8359375 ],
#          [-0.83333333]],
#
#         [[-0.85416667],
#          [-0.86197917],
#          [-0.86979167],
#          ...,
#          [-0.83072917],
#          [-0.82291667],
#          [-0.81510417]],
#
#         [[-0.86197917],
#          [-0.87760417],
#          [-0.88020833],
#          ...,
#          [-0.70052083],
#          [-0.66927083],
#          [-0.65364583]],
#
#         ...,
#
#         [[-0.30729167],
#          [-0.3203125 ],
#          [-0.31510417],
#          ...,
#          [-0.19791667],
#          [-0.27604167],
#          [-0.41666667]],
#
#         [[-0.3203125 ],
#          [-0.328125  ],
#          [-0.31510417],
#          ...,
#          [-0.26041667],
#          [-0.34895833],
#          [-0.5390625 ]],
#
#         [[-0.3359375 ],
#          [-0.3359375 ],
#          [-0.3125    ],
#          ...,
#          [-0.41666667],
#          [-0.51822917],
#          [-0.65625   ]]],
#
#
#        [[[-0.8125    ],
#          [-0.8203125 ],
#          [-0.83072917],
#          ...,
#          [-0.8671875 ],
#          [-0.88020833],
#          [-0.87239583]],
#
#         [[-0.82552083],
#          [-0.828125  ],
#          [-0.83333333],
#          ...,
#          [-0.875     ],
#          [-0.87239583],
#          [-0.86458333]],
#
#         [[-0.83333333],
#          [-0.82552083],
#          [-0.83854167],
#          ...,
#          [-0.875     ],
#          [-0.875     ],
#          [-0.875     ]],
#
#         ...,
#
#         [[-0.8828125 ],
#          [-0.8828125 ],
#          [-0.8828125 ],
#          ...,
#          [-0.89322917],
#          [-0.89322917],
#          [-0.89322917]],
#
#         [[-0.875     ],
#          [-0.88020833],
#          [-0.875     ],
#          ...,
#          [-0.89322917],
#          [-0.90104167],
#          [-0.8984375 ]],
#
#         [[-0.88020833],
#          [-0.8828125 ],
#          [-0.8828125 ],
#          ...,
#          [-0.88541667],
#          [-0.89583333],
#          [-0.90104167]]],
#
#
#        [[[-0.49739583],
#          [-0.51822917],
#          [-0.4921875 ],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         [[-0.53385417],
#          [-0.546875  ],
#          [-0.15885417],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         [[-0.5625    ],
#          [-0.59895833],
#          [-0.00520833],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         ...,
#
#         [[-0.15885417],
#          [-0.43489583],
#          [-0.52864583],
#          ...,
#          [ 0.73958333],
#          [ 0.75520833],
#          [ 0.70833333]],
#
#         [[ 0.15364583],
#          [-0.3515625 ],
#          [-0.4609375 ],
#          ...,
#          [ 0.73697917],
#          [ 0.35416667],
#          [-0.04947917]],
#
#         [[ 0.32552083],
#          [-0.03125   ],
#          [-0.0078125 ],
#          ...,
#          [ 0.69791667],
#          [ 0.20052083],
#          [-0.11197917]]]])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from sklearn.utils import shuffle

# %%
# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=False,
    vertical_flip=False,
    fill_mode='nearest'
)

# %%
# Example of applying data augmentation to the training set
augmented_images = []
for img in X_train_grey_norm:
    augmented_img = datagen.random_transform(img)
    augmented_images.append(augmented_img)

# %%
i = 1000
plt.imshow(X_train_grey[i].squeeze(),cmap='gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_grey_norm[i].squeeze(),cmap = 'gray')

# %%
i = 1000
plt.imshow(X_test_grey[i].squeeze(),cmap='gray')
plt.figure()
plt.imshow(X_test[i])
plt.figure()
plt.imshow(X_test_grey_norm[i].squeeze(),cmap = 'gray')

# %%
i = 1000
plt.imshow(X_validation_grey[i].squeeze(),cmap='gray')
plt.figure()
plt.imshow(X_validation[i])
plt.figure()
plt.imshow(X_validation_grey_norm[i].squeeze(),cmap = 'gray')

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard

# %%
cnn_model = Sequential()

# Input layer implicitly defined by specifying input_shape in the first layer
cnn_model.add(Conv2D(filters=6, kernel_size=(5, 5), activation='relu', input_shape=(32, 32, 1)))
cnn_model.add(AveragePooling2D(2, 2))

cnn_model.add(Conv2D(filters=16, kernel_size=(5, 5), activation='relu'))
cnn_model.add(AveragePooling2D(2, 2))

cnn_model.add(Flatten())
cnn_model.add(Dense(units=120, activation='relu'))
cnn_model.add(Dense(units=84, activation='relu'))
cnn_model.add(Dense(units=43, activation='softmax'))

# %%
cnn_model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])

# %%
# Train the model with augmented data
history = cnn_model.fit(datagen.flow(X_train_grey_norm, y_train, batch_size=500),
                        steps_per_epoch=int(len(X_train_grey_norm) / 500),
                        epochs=50,
                        verbose=1,
                        validation_data=(X_validation_grey_norm, y_validation))
# Out:
# Epoch 1/50
# C:\Users\SEC\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.0703 - loss: 3.5475 - val_accuracy: 0.1694 - val_loss: 3.2463
# Epoch 2/50
#  1/69 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.1840 - loss: 3.0890
# C:\Users\SEC\anaconda3\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1840 - loss: 3.0890 - val_accuracy: 0.1812 - val_loss: 3.2361
# Epoch 3/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.2116 - loss: 2.9450 - val_accuracy: 0.3828 - val_loss: 2.2485
# Epoch 4/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3360 - loss: 2.4521 - val_accuracy: 0.3873 - val_loss: 2.2403
# Epoch 5/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.3628 - loss: 2.2982 - val_accuracy: 0.4757 - val_loss: 1.7616
# Epoch 6/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4360 - loss: 1.9786 - val_accuracy: 0.4882 - val_loss: 1.7530
# Epoch 7/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 211ms/step - accuracy: 0.4608 - loss: 1.9001 - val_accuracy: 0.5723 - val_loss: 1.4553
# Epoch 8/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5380 - loss: 1.6289 - val_accuracy: 0.5664 - val_loss: 1.4647
# Epoch 9/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 207ms/step - accuracy: 0.5352 - loss: 1.6183 - val_accuracy: 0.5558 - val_loss: 1.3847
# Epoch 10/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5640 - loss: 1.4868 - val_accuracy: 0.5764 - val_loss: 1.3500
# Epoch 11/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 210ms/step - accuracy: 0.5836 - loss: 1.4296 - val_accuracy: 0.6488 - val_loss: 1.2178
# Epoch 12/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6480 - loss: 1.2732 - val_accuracy: 0.6467 - val_loss: 1.2245
# Epoch 13/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 221ms/step - accuracy: 0.6322 - loss: 1.2720 - val_accuracy: 0.6580 - val_loss: 1.1520
# Epoch 14/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5920 - loss: 1.3871 - val_accuracy: 0.6565 - val_loss: 1.1386
# Epoch 15/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 217ms/step - accuracy: 0.6679 - loss: 1.1429 - val_accuracy: 0.6889 - val_loss: 1.1212
# Epoch 16/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6720 - loss: 1.1979 - val_accuracy: 0.6964 - val_loss: 1.0951
# Epoch 17/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.6956 - loss: 1.0615 - val_accuracy: 0.6810 - val_loss: 1.0487
# Epoch 18/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7140 - loss: 1.0295 - val_accuracy: 0.6789 - val_loss: 1.0432
# Epoch 19/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.7112 - loss: 0.9823 - val_accuracy: 0.7317 - val_loss: 0.9692
# Epoch 20/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7360 - loss: 0.9521 - val_accuracy: 0.7277 - val_loss: 0.9594
# Epoch 21/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 217ms/step - accuracy: 0.7237 - loss: 0.9327 - val_accuracy: 0.7383 - val_loss: 0.8944
# Epoch 22/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7680 - loss: 0.8359 - val_accuracy: 0.7417 - val_loss: 0.8954
# Epoch 23/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 211ms/step - accuracy: 0.7478 - loss: 0.8664 - val_accuracy: 0.7118 - val_loss: 0.9700
# Epoch 24/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7240 - loss: 0.9478 - val_accuracy: 0.7256 - val_loss: 0.9366
# Epoch 25/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 218ms/step - accuracy: 0.7585 - loss: 0.8192 - val_accuracy: 0.7347 - val_loss: 0.9062
# Epoch 26/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7780 - loss: 0.7476 - val_accuracy: 0.7420 - val_loss: 0.8987
# Epoch 27/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 217ms/step - accuracy: 0.7774 - loss: 0.7704 - val_accuracy: 0.7503 - val_loss: 0.8521
# Epoch 28/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7400 - loss: 0.7941 - val_accuracy: 0.7671 - val_loss: 0.8229
# Epoch 29/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 216ms/step - accuracy: 0.7783 - loss: 0.7391 - val_accuracy: 0.7633 - val_loss: 0.8248
# Epoch 30/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7780 - loss: 0.7817 - val_accuracy: 0.7728 - val_loss: 0.7903
# Epoch 31/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 215ms/step - accuracy: 0.7981 - loss: 0.6887 - val_accuracy: 0.7703 - val_loss: 0.7629
# Epoch 32/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7820 - loss: 0.6665 - val_accuracy: 0.7712 - val_loss: 0.7596
# Epoch 33/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 215ms/step - accuracy: 0.8062 - loss: 0.6567 - val_accuracy: 0.8009 - val_loss: 0.7268
# Epoch 34/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8600 - loss: 0.5824 - val_accuracy: 0.8011 - val_loss: 0.7278
# Epoch 35/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 228ms/step - accuracy: 0.8166 - loss: 0.6313 - val_accuracy: 0.7755 - val_loss: 0.7650
# Epoch 36/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7500 - loss: 0.8021 - val_accuracy: 0.7853 - val_loss: 0.7729
# Epoch 37/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 228ms/step - accuracy: 0.8210 - loss: 0.6147 - val_accuracy: 0.7896 - val_loss: 0.7248
# Epoch 38/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8280 - loss: 0.5966 - val_accuracy: 0.7873 - val_loss: 0.7311
# Epoch 39/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 217ms/step - accuracy: 0.8288 - loss: 0.5833 - val_accuracy: 0.7805 - val_loss: 0.7479
# Epoch 40/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8220 - loss: 0.5934 - val_accuracy: 0.7807 - val_loss: 0.7511
# Epoch 41/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.8293 - loss: 0.5740 - val_accuracy: 0.8050 - val_loss: 0.6764
# Epoch 42/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8560 - loss: 0.5077 - val_accuracy: 0.8111 - val_loss: 0.6662
# Epoch 43/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.8410 - loss: 0.5385 - val_accuracy: 0.8095 - val_loss: 0.6807
# Epoch 44/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8640 - loss: 0.4521 - val_accuracy: 0.8023 - val_loss: 0.6855
# Epoch 45/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 211ms/step - accuracy: 0.8424 - loss: 0.5222 - val_accuracy: 0.8079 - val_loss: 0.6524
# Epoch 46/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8720 - loss: 0.4573 - val_accuracy: 0.8045 - val_loss: 0.6604
# Epoch 47/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 18s 235ms/step - accuracy: 0.8498 - loss: 0.5056 - val_accuracy: 0.8172 - val_loss: 0.6592
# Epoch 48/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8860 - loss: 0.4182 - val_accuracy: 0.8138 - val_loss: 0.6795
# Epoch 49/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 221ms/step - accuracy: 0.8578 - loss: 0.4920 - val_accuracy: 0.8023 - val_loss: 0.7134
# Epoch 50/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8360 - loss: 0.5400 - val_accuracy: 0.8018 - val_loss: 0.7359

# %%
#MODEL EVALUATION

# %%
score=cnn_model.evaluate(X_test_grey_norm,y_test)
print('Test Acuuracy: {}'.format(score[1]))
# Out:
# 395/395 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8248 - loss: 0.7399
# Test Acuuracy: 0.8199524879455566

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
accuracy=history.history['accuracy']
val_accuracy=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

# %%
epochs=range(len(accuracy))

plt.plot(epochs,accuracy,'bo',label='Training Accuracy')
plt.plot(epochs,val_accuracy,'b',label='Val Accuracy')
plt.title("Training and Validation Accuracy")
plt.legend()

# %%
plt.plot(epochs,loss,'ro',label='Training loss')
plt.plot(epochs,val_loss,'r',label='Val loss')
plt.title("Training and Validation Loss")

plt.legend()

# %%
predicted_classes = cnn_model.predict(X_test_grey_norm)
y_true = y_test
# Out:
# 395/395 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
from sklearn.metrics import confusion_matrix
predicted_classes = np.argmax(predicted_classes, axis=1)
cm = confusion_matrix(y_true,predicted_classes)
plt.figure(figsize=(25,25))
sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', cbar_kws={'label': 'Scale'}, annot_kws={"size": 15}, linewidths=1, linecolor='black')
# Out:
# <Axes: >

# %%
L = 7
W = 7

fig, axes = plt.subplots(L, W, figsize=(12, 12))
axes = axes.ravel()

for i in np.arange(0, L * W):
    axes[i].imshow(X_test[i], cmap='gray')
    axes[i].set_title('Prediction = {}\n True {}'.format(predicted_classes[i],y_true[i]))
    axes[i].axis('off')  # Turn off axis for better visualization

plt.subplots_adjust(wspace = 0)
plt.tight_layout()
plt.show()

# %%
class_names = {
    0: 'Speed limit (20km/h)',
    1: 'Speed limit (30km/h)',
    2: 'Speed limit (50km/h)',
    3: 'Speed limit (60km/h)',
    4: 'Speed limit (70km/h)',
    5: 'Speed limit (80km/h)',
    6: 'End of speed limit (80km/h)',
    7: 'Speed limit (100km/h)',
    8: 'Speed limit (120km/h)',
    9: 'No passing',
    10: 'No passing for vehicles over 3.5 metric tons',
    11: 'Right-of-way at the next intersection',
    12: 'Priority road',
    13: 'Yield',
    14: 'Stop',
    15: 'No vehicles',
    16: 'Vehicles over 3.5 metric tons prohibited',
    17: 'No entry',
    18: 'General caution',
    19: 'Dangerous curve to the left',
    20: 'Dangerous curve to the right',
    21: 'Double curve',
    22: 'Bumpy road',
    23: 'Slippery road',
    24: 'Road narrows on the right',
    25: 'Road work',
    26: 'Traffic signals',
    27: 'Pedestrians',
    28: 'Children crossing',
    29: 'Bicycles crossing',
    30: 'Beware of ice/snow',
    31: 'Wild animals crossing',
    32: 'End of all speed and passing limits',
    33: 'Turn right ahead',
    34: 'Turn left ahead',
    35: 'Ahead only',
    36: 'Go straight or right',
    37: 'Go straight or left',
    38: 'Keep right',
    39: 'Keep left',
    40: 'Roundabout mandatory',
    41: 'End of no passing',
    42: 'End of no passing by vehicles over 3.5 metric tons'
}

# %%
def get_class_name(class_id):
    return class_names.get(class_id, "Unknown Class")

# Example usage:
predicted_class = 14
print(f"The predicted class is: {get_class_name(predicted_class)}")
# Out:
# The predicted class is: Stop

# %%
# Save the trained model in the native Keras format
cnn_model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
cnn_model.save("cnn_model.keras")

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam

# Load the saved model
model = tf.keras.models.load_model("cnn_model.keras")

# Ensure the model is compiled (re-compile if necessary)
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Dictionary to map class numbers to their respective names
class_names = {
    0: 'Speed limit (20km/h)',
    1: 'Speed limit (30km/h)',
    2: 'Speed limit (50km/h)',
    3: 'Speed limit (60km/h)',
    4: 'Speed limit (70km/h)',
    5: 'Speed limit (80km/h)',
    6: 'End of speed limit (80km/h)',
    7: 'Speed limit (100km/h)',
    8: 'Speed limit (120km/h)',
    9: 'No passing',
    10: 'No passing for vehicles over 3.5 metric tons',
    11: 'Right-of-way at the next intersection',
    12: 'Priority road',
    13: 'Yield',
    14: 'Stop',
    15: 'No vehicles',
    16: 'Vehicles over 3.5 metric tons prohibited',
    17: 'No entry',
    18: 'General caution',
    19: 'Dangerous curve to the left',
    20: 'Dangerous curve to the right',
    21: 'Double curve',
    22: 'Bumpy road',
    23: 'Slippery road',
    24: 'Road narrows on the right',
    25: 'Road work',
    26: 'Traffic signals',
    27: 'Pedestrians',
    28: 'Children crossing',
    29: 'Bicycles crossing',
    30: 'Beware of ice/snow',
    31: 'Wild animals crossing',
    32: 'End of all speed and passing limits',
    33: 'Turn right ahead',
    34: 'Turn left ahead',
    35: 'Ahead only',
    36: 'Go straight or right',
    37: 'Go straight or left',
    38: 'Keep right',
    39: 'Keep left',
    40: 'Roundabout mandatory',
    41: 'End of no passing',
    42: 'End of no passing by vehicles over 3.5 metric tons'
}

# %%
def get_class_name(class_id):
    return class_names.get(class_id, "Unknown Class")

def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(32, 32), color_mode='grayscale')
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = (img - 128) / 128  # Normalize the image
    return img

# %%
def predict_image(img_path):
    img = preprocess_image(img_path)
    prediction = model.predict(img)
    predicted_class = np.argmax(prediction)
    class_name = get_class_name(predicted_class)
    return predicted_class, class_name

def plot_image_with_prediction(img_path):
    predicted_class, class_name = predict_image(img_path)
    img = image.load_img(img_path, target_size=(32, 32), color_mode='grayscale')
    plt.imshow(img, cmap='gray')
    plt.title(f'Prediction: {class_name} ({predicted_class})')
    plt.axis('off')
    plt.show()

# %%
img_path = r"C:\Users\SEC\Downloads\Screenshot_9-7-2024_194831_www.godigit.com.jpeg"  # Replace with the path to your image
plot_image_with_prediction(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step

# %%
img_path = r"C:\Users\SEC\Pictures\Screenshots\Screenshot 2024-07-09 200001.png"  # Replace with the path to your image
plot_image_with_prediction(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
